# %% [markdown]
# ## Functions and Parameters

# %%
def say_hi():
    print("hi")

# %%
say_hi()
# Out:
# hi

# %%
say_hi
# Out:
# <function __main__.say_hi>

# %%
def say_something_specific(something_specific):
    print(something_specific)

# %%
say_something_specific("something specific")
# Out:
# something specific

# %% [markdown]
# ## Review of Dataframes

# %% [markdown]
# Import packages

# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# Import the data

# %%
train_stances = pd.read_csv("../train_stances.csv", encoding = "utf-8")
train_bodies = pd.read_csv("../train_bodies.csv", encoding = "utf-8")

# %% [markdown]
# df.columns

# %%
train_stances.columns
# Out:
# Index(['Headline', 'Body ID', 'Stance'], dtype='object')

# %%
train_bodies.columns
# Out:
# Index(['Body ID', 'articleBody'], dtype='object')

# %% [markdown]
# df.shape

# %%
train_stances.shape
# Out:
# (49972, 3)

# %%
train_bodies.shape
# Out:
# (1683, 2)

# %% [markdown]
# viewing the data

# %%
train_stances.head()
# Out:
#                                                                                                               Headline  \
# 0  Police find mass graves with at least '15 bodies' near Mexico town where 43 students disappeared after police clash
# 1  Hundreds of Palestinians flee floods in Gaza as Israel opens dams
# 2  Christian Bale passes on role of Steve Jobs, actor reportedly felt he wasn't right for part
# 3  HBO and Apple in Talks for $15/Month Apple TV Streaming Service Launching in April
# 4  Spider burrowed through tourist's stomach and up into his chest
#
#    Body ID     Stance
# 0  712      unrelated
# 1  158      agree
# 2  137      unrelated
# 3  1034     unrelated
# 4  1923     disagree

# %%
train_bodies.head()
# Out:
#    Body ID  \
# 0  0
# 1  4
# 2  5
# 3  6
# 4  7
#
# ...

# %% [markdown]
# Merging the data

# %%
train_data = pd.merge(train_bodies, train_stances, on='Body ID')

# %%
train_data.head()
# Out:
#    Body ID  \
# 0  0
# 1  0
# 2  0
# 3  0
# 4  0
#
# ...

# %% [markdown]
# Selecting the data

# %%
train_data.iloc[0]
# Out:
# Body ID        0
# ...

# %%
train_data['Stance']
# Out:
# 0        unrelated
# 1        unrelated
# 2        unrelated
# 3        unrelated
# 4        unrelated
# 5        unrelated
# 6        unrelated
# 7        unrelated
# 8        unrelated
# 9        unrelated
# 10       unrelated
# 11       unrelated
# 12       unrelated
# 13       unrelated
# 14       unrelated
# 15       unrelated
# 16       unrelated
# 17       unrelated
# 18       unrelated
# 19       unrelated
# 20       unrelated
# 21       unrelated
# 22       unrelated
# 23       unrelated
# 24       agree
# 25       unrelated
# 26       unrelated
# 27       unrelated
# 28       unrelated
# 29       unrelated
#            ...
# 49942    unrelated
# 49943    unrelated
# 49944    unrelated
# 49945    unrelated
# 49946    unrelated
# 49947    unrelated
# 49948    unrelated
# 49949    unrelated
# 49950    unrelated
# 49951    unrelated
# 49952    discuss
# 49953    unrelated
# 49954    discuss
# 49955    discuss
# 49956    unrelated
# 49957    unrelated
# 49958    unrelated
# ...

# %%
train_data[train_data['Stance'] == 'agree']
# Out:
#        Body ID  \
# 24     0
# 199    8
# 241    9
# 242    9
# 363    13
# 402    16
# 410    17
# 455    18
# 499    24
# 500    25
# 505    26
# 599    26
# 614    27
# 894    35
# 923    36
# 1148   43
# 1154   44
# 1199   48
# 1252   55
# 1256   56
# 1377   65
# 1382   68
# 1398   70
# 1556   80
# 1633   81
# 1691   82
# 1721   86
# 1725   86
# 1780   88
# 1798   89
# ...    ..
# 49606  2524
# 49608  2524
# 49611  2524
# 49616  2524
# 49621  2524
# 49628  2524
# 49631  2524
# 49632  2524
# 49633  2524
# 49638  2524
# 49648  2525
# 49660  2525
# 49665  2525
# 49679  2525
# 49690  2525
# 49699  2525
# 49701  2525
# 49856  2529
# 49857  2529
# 49858  2529
# 49860  2529
# 49861  2529
# 49862  2529
# 49863  2529
# 49966  2532
# 49967  2532
# 49968  2532
# 49969  2532
# 49970  2532
# 49971  2532
#
# ...

# %% [markdown]
# ## Documentation

# %% [markdown]
# 'How to iterate over a pandas dataframe'

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/version/0.17.0/generated/pandas.DataFrame.iterrows.html

# %% [markdown]
# ## Errors

# %%
test_data.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-fe207cd62698> in <module>()
# ----> 1 test_data.shape
#
# NameError: name 'test_data' is not defined

# %%
train_data.shade
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-58074cfc477e> in <module>()
# ----> 1 train_data.shade
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'shade'

# %%
train_data.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-f76d34cc24c1> in <module>()
# ----> 1 train_data.shape()
#
# TypeError: 'tuple' object is not callable

# %%
train_data['stand']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'stand'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-0e2ba13b72dc> in <module>()
# ----> 1 train_data['stand']
#
# ...

# %%
a = [1,2,3]

# %%
a[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-35-5c463c0247cc> in <module>()
# ----> 1 a[10]
#
# IndexError: list index out of range

# %%
train_stances = pd.read_csv("train_stances.csv", encoding = "utf-8")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a32775f9c7cf> in <module>()
# ----> 1 train_stances = pd.read_csv("../train_stances.csv", encoding = "utf-8")
#
# NameError: name 'pd' is not defined

# %% [markdown]
# # Rule-Based Classifiers

# %% [markdown]
# First, we'll write a very simple spam classifier.

# %%
spam_words = ["you won't believe", "wire", "CASH"] # TODO: Fill in here

# %%
def classify_spam(email):
    for word in email:
        if word in spam_words:
            return "spam"
    return "ham"

# %%
email = "SIX chances to win CASH!"  # TODO: Fill in here
classification = classify_spam(email)
print(classification)
# Out:
# ham
